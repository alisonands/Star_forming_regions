# %%
conda uninstall -c conda-forge gammapy
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   removed specs:
#     - gammapy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alabaster-0.7.13           |     pyhd8ed1ab_0          18 KB  conda-forge
#     anaconda-client-1.11.1     |     pyhd8ed1ab_0          67 KB  conda-forge
#     anaconda-project-0.11.1    |     pyhd8ed1ab_0         225 KB  conda-forge
#     anyio-3.6.2                |     pyhd8ed1ab_0          83 KB  conda-forge
#     applaunchservices-0.3.0    |     pyhd8ed1ab_2           9 KB  conda-forge
#     appnope-0.1.3              |     pyhd8ed1ab_0           8 KB  conda-forge
#     argon2-cffi-21.3.0         |     pyhd8ed1ab_0          15 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|   py38hef030d1_3          32 KB  conda-forge
# ...
